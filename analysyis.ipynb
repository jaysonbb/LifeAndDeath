# %%
import pandas as pd
import seaborn as sns

# %%
# read in data
game_df = pd.read_csv('data/game_data.csv')
player_df = pd.read_csv('data/player_data.csv')

# %%
sns.histplot(game_df['cards_drawn'])
# Out:
# <AxesSubplot:xlabel='cards_drawn', ylabel='Count'>

# %%
sns.histplot(game_df['total_payout'])
# Out:
# <AxesSubplot:xlabel='total_payout', ylabel='Count'>

# %%
sns.scatterplot(x=game_df['cards_drawn'], y=game_df['total_payout'])
# Out:
# <AxesSubplot:xlabel='cards_drawn', ylabel='total_payout'>
